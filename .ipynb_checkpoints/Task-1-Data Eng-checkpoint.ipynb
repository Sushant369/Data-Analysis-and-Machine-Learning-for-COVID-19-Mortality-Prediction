# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("data/owid-covid-data.xlsx")

# %%
df.head()
# Out:
#   continent     location        date total_cases_per_million  \
# 0       NaN          NaN         NaN             cummulative
# 1      Asia  Afghanistan  2023-02-14                5082.476
# 2       NaN       Africa  2023-02-14                8768.251
# 3    Europe      Albania  2023-02-14              117602.605
# 4    Africa      Algeria  2023-02-14                6044.309
#
#    new_cases_per_million total_deaths_per_million  new_deaths_per_million  \
# 0                    NaN              cummulative                     NaN
# 1                  0.608                  191.982                    0.00
# 2                  0.390                  180.588                    0.01
# 3                  3.166                 1265.165                    0.00
# 4                  0.000                  153.241                    0.00
#
#    reproduction_rate  icu_patients_per_million  hosp_patients_per_million  \
# 0                NaN                       NaN                        NaN
# 1                NaN                       NaN                        NaN
# 2                NaN                       NaN                        NaN
# 3                NaN                       NaN                        NaN
# 4                NaN                       NaN                        NaN
#
#    ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0  ...           NaN                     NaN                         NaN
# 1  ...           NaN                  37.746                        0.50
# 2  ...           NaN                     NaN                         NaN
# 3  ...          51.2                     NaN                        2.89
# 4  ...          30.4                  83.741                        1.90
#
#    life_expectancy  human_development_index    population  \
# 0              NaN                      NaN           NaN
# 1            64.83                    0.511  4.112877e+07
# 2              NaN                      NaN  1.426737e+09
# 3            78.57                    0.795  2.842318e+06
# 4            76.88                    0.748  4.490323e+07
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#   excess_mortality  excess_mortality_cumulative_per_million
# 0              NaN                                      NaN
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
#
# [5 rows x 52 columns]

# %%
df = df[['continent',
'location','date',
'total_cases_per_million',
'new_cases_per_million',
'total_deaths_per_million',
'new_deaths_per_million','reproduction_rate'
,'icu_patients_per_million',
'hosp_patients_per_million',
'total_tests_per_thousand',
'new_tests_per_thousand',
'tests_per_case',
'total_boosters',
'new_vaccinations',
'total_vaccinations_per_hundred',
'people_vaccinated_per_hundred',
'people_fully_vaccinated_per_hundred',
'total_boosters_per_hundred',
'new_vaccinations_smoothed_per_million',
'new_people_vaccinated_smoothed_per_hundred',
'stringency_index',
'population_density',
'median_age',
'aged_65_older',
'aged_70_older',
'gdp_per_capita',
'extreme_poverty',
'cardiovasc_death_rate',
'diabetes_prevalence',
'female_smokers',
'male_smokers',
'handwashing_facilities',
'hospital_beds_per_thousand','life_expectancy',
'human_development_index',
'population',
'excess_mortality',
'excess_mortality_cumulative_per_million']]

# %%
df = df.iloc[1:,:]

# %%
summary_df = pd.DataFrame()
summary_df['Null values'] = df.isna().sum()

# %%
summary_df['dtypes'] = df.dtypes

# %%
summary_df
# Out:
#                                             Null values   dtypes
# continent                                         14454   object
# location                                              0   object
# date                                                  0   object
# total_cases_per_million                           15488   object
# new_cases_per_million                             15763  float64
# total_deaths_per_million                          35128   object
# new_deaths_per_million                            35228  float64
# reproduction_rate                                 72591  float64
# icu_patients_per_million                         222992  float64
# hosp_patients_per_million                        219953  float64
# total_tests_per_thousand                         178021  float64
# new_tests_per_thousand                           182005  float64
# tests_per_case                                   163060  float64
# total_boosters                                   216502  float64
# new_vaccinations                                 197551  float64
# total_vaccinations_per_hundred                   185302  float64
# people_vaccinated_per_hundred                    188402  float64
# people_fully_vaccinated_per_hundred              191056  float64
# total_boosters_per_hundred                       216502  float64
# new_vaccinations_smoothed_per_million            104448  float64
# new_people_vaccinated_smoothed_per_hundred       104576  float64
# stringency_index                                  72214  float64
# population_density                                33059  float64
# median_age                                        49907  float64
# aged_65_older                                     52094  float64
# aged_70_older                                     50992  float64
# gdp_per_capita                                    50244  float64
# extreme_poverty                                  122488  float64
# cardiovasc_death_rate                             50523  float64
# diabetes_prevalence                               39630  float64
# female_smokers                                   100476  float64
# male_smokers                                     102623  float64
# handwashing_facilities                           155338  float64
# hospital_beds_per_thousand                        72916  float64
# life_expectancy                                   21165  float64
# human_development_index                           55151  float64
# population                                         1104  float64
# excess_mortality                                 248877  float64
# excess_mortality_cumulative_per_million          248877  float64

# %%
df['location'] = pd.Categorical(df['location'])
# Out:
# /var/folders/g8/ryts82jd3c33vl83y_np4dzm0000gn/T/ipykernel_66788/1938827158.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['location'] = pd.Categorical(df['location'])
#                 continent  location  date  total_cases_per_million  \
# location
# Afghanistan             0         0     0                        0
# Africa               1098         0     0                        1
# Albania                 0         0     0                       13
# Algeria                 0         0     0                        0
# Andorra                 0         0     0                        0
# ...                   ...       ...   ...                      ...
# Western Sahara          0         0     0                        1
# World                1120         0     0                        0
# Yemen                   0         0     0                        0
# Zambia                  0         0     0                        0
# Zimbabwe                0         0     0                        0
#
#                 new_cases_per_million  total_deaths_per_million  \
# location
# Afghanistan                         3                        28
# Africa                              0                        24
# Albania                            13                        15
# Algeria                             0                        16
# Andorra                             0                        20
# ...                               ...                       ...
# Western Sahara                      1                         1
# World                               0                         0
# Yemen                               1                        20
# Zambia                              0                        15
# Zimbabwe                            7                         3
#
#                 new_deaths_per_million  reproduction_rate  \
# location
# Afghanistan                         28                 77
# Africa                               0               1098
# Albania                             15                 71
# Algeria                             16                 69
# Andorra                             21                 64
# ...                                ...                ...
# Western Sahara                       1                  1
# World                                0                 44
# Yemen                               20                 79
# Zambia                              15                 87
# Zimbabwe                             3                112
#
#                 icu_patients_per_million  hosp_patients_per_million  ...  \
# location                                                             ...
# Afghanistan                         1087                       1087  ...
# Africa                              1098                       1098  ...
# Albania                             1086                       1086  ...
# Algeria                              262                       1086  ...
# Andorra                             1080                       1080  ...
# ...                                  ...                        ...  ...
# Western Sahara                         1                          1  ...
# World                               1120                       1120  ...
# Yemen                               1041                       1041  ...
# Zambia                              1064                       1064  ...
# Zimbabwe                            1062                       1062  ...
#
#                 diabetes_prevalence  female_smokers  male_smokers  \
# location
# Afghanistan                       0            1087          1087
# Africa                         1098            1098          1098
# Albania                           0               0             0
# Algeria                           0               0             0
# Andorra                           0               0             0
# ...                             ...             ...           ...
# Western Sahara                    1               1             1
# World                             0               0             0
# Yemen                             0               0             0
# Zambia                            0               0             0
# Zimbabwe                          0               0             0
#
#                 handwashing_facilities  hospital_beds_per_thousand  \
# location
# Afghanistan                          0                           0
# Africa                            1098                        1098
# Albania                           1086                           0
# Algeria                              0                           0
# Andorra                           1080                        1080
# ...                                ...                         ...
# Western Sahara                       1                           1
# World                                0                           0
# Yemen                                0                           0
# Zambia                               0                           0
# Zimbabwe                             0                           0
#
#                 life_expectancy  human_development_index  population  \
# location
# Afghanistan                   0                        0           0
# Africa                     1098                     1098           0
# Albania                       0                        0           0
# Algeria                       0                        0           0
# Andorra                       0                        0           0
# ...                         ...                      ...         ...
# Western Sahara                0                        1           0
# World                         0                        0           0
# Yemen                         0                        0           0
# Zambia                        0                        0           0
# Zimbabwe                      0                        0           0
#
#                 excess_mortality  excess_mortality_cumulative_per_million
# location
# Afghanistan                 1087                                     1087
# Africa                      1098                                     1098
# Albania                     1054                                     1054
# Algeria                     1075                                     1075
# Andorra                     1058                                     1058
# ...                          ...                                      ...
# Western Sahara                 1                                        1
# World                       1120                                     1120
# Yemen                       1041                                     1041
# Zambia                      1064                                     1064
# Zimbabwe                    1062                                     1062
#
# [248 rows x 39 columns]

# %%
#number of countries
df['location'].value_counts().count()
# Out:
# 248

# %%
# export to csv to view
# country wise null values:
empty_per_country  = df.isna().groupby(df.location).sum()
empty_per_country.to_csv('empty_per_country.csv')

# %%
# continent wise null values:
empty_per_continent = df.isna().groupby(df.continent).sum()
empty_per_continent.to_csv("empty_per_continent.csv")

# %%
df['date'] = pd.to_datetime(df.date,format = '%Y/%m/%d')
df['continent'] = pd.Categorical(df['continent'])

# %%
def ret_data(group):
    group['']
    return group

# %%
null_df = df.groupby(pd.Grouper(key='date', freq='W')).apply(ret_data)
# Out:
# /var/folders/g8/ryts82jd3c33vl83y_np4dzm0000gn/T/ipykernel_66788/2344326002.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   null_df = df.groupby(pd.Grouper(key='date', freq='W')).apply(ret_data)

# %%
null_df
# Out:
#             continent           location       date total_cases_per_million  \
# 257407  South America          Argentina 2020-01-01                     NaN
# 257408  North America             Mexico 2020-01-01                     NaN
# 257405  South America          Argentina 2020-01-02                     NaN
# 257406  North America             Mexico 2020-01-02                     NaN
# 257403  South America          Argentina 2020-01-03                     NaN
# ...               ...                ...        ...                     ...
# 227           Oceania  Wallis and Futuna 2023-02-14              295532.942
# 228               NaN              World 2023-02-14               84400.794
# 229              Asia              Yemen 2023-02-14                 354.487
# 230            Africa             Zambia 2023-02-14               17100.741
# 231            Africa           Zimbabwe 2023-02-14               16119.749
#
#         new_cases_per_million total_deaths_per_million  \
# 257407                    NaN                      NaN
# 257408                    NaN                      NaN
# 257405                    NaN                      NaN
# 257406                    NaN                      NaN
# 257403                    NaN                      NaN
# ...                       ...                      ...
# 227                     0.000                  603.656
# 228                    22.487                  859.646
# 229                     0.000                   64.072
# 230                     0.000                  202.371
# 231                       NaN                  346.741
#
#         new_deaths_per_million  reproduction_rate  icu_patients_per_million  \
# 257407                     NaN                NaN                       NaN
# 257408                     NaN                NaN                       NaN
# 257405                     NaN                NaN                       NaN
# 257406                     NaN                NaN                       NaN
# 257403                     NaN                NaN                       NaN
# ...                        ...                ...                       ...
# 227                      0.000                NaN                       NaN
# 228                      0.149                NaN                       NaN
# 229                      0.000                NaN                       NaN
# 230                      0.000                NaN                       NaN
# 231                      0.000                NaN                       NaN
#
#         hosp_patients_per_million  ...  diabetes_prevalence  female_smokers  \
# 257407                        NaN  ...                 5.50          16.200
# 257408                        NaN  ...                13.06           6.900
# 257405                        NaN  ...                 5.50          16.200
# 257406                        NaN  ...                13.06           6.900
# 257403                        NaN  ...                 5.50          16.200
# ...                           ...  ...                  ...             ...
# 227                           NaN  ...                  NaN             NaN
# 228                           NaN  ...                 8.51           6.434
# 229                           NaN  ...                 5.35           7.600
# 230                           NaN  ...                 3.94           3.100
# 231                           NaN  ...                 1.82           1.600
#
#         male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 257407        27.700                     NaN                       5.000
# 257408        21.400                  87.847                       1.380
# 257405        27.700                     NaN                       5.000
# 257406        21.400                  87.847                       1.380
# 257403        27.700                     NaN                       5.000
# ...              ...                     ...                         ...
# 227              NaN                     NaN                         NaN
# 228           34.635                  60.130                       2.705
# 229           29.200                  49.542                       0.700
# 230           24.700                  13.938                       2.000
# 231           30.700                  36.791                       1.700
#
#         life_expectancy  human_development_index    population  \
# 257407            76.67                    0.845  4.551032e+07
# 257408            75.05                    0.779  1.275041e+08
# 257405            76.67                    0.845  4.551032e+07
# 257406            75.05                    0.779  1.275041e+08
# 257403            76.67                    0.845  4.551032e+07
# ...                 ...                      ...           ...
# 227               79.94                      NaN  1.159600e+04
# 228               72.58                    0.737  7.975105e+09
# 229               66.12                    0.470  3.369661e+07
# 230               63.89                    0.584  2.001767e+07
# 231               61.49                    0.571  1.632054e+07
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 257407               NaN                                      NaN
# 257408               NaN                                      NaN
# 257405               NaN                                      NaN
# 257406               NaN                                      NaN
# 257403               NaN                                      NaN
# ...                  ...                                      ...
# 227                  NaN                                      NaN
# 228                  NaN                                      NaN
# 229                  NaN                                      NaN
# 230                  NaN                                      NaN
# 231                  NaN                                      NaN
#
# [257408 rows x 39 columns]

# %%
type(null_df)
# Out:
# pandas.core.frame.DataFrame

# %%
 null_df.isna().groupby(df.dates).sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/g8/ryts82jd3c33vl83y_np4dzm0000gn/T/ipykernel_66788/4265621249.py in <module>
# ----> 1 null_df.isna().groupby(df.dates).sum()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dates'

# %%
null_df
# Out:
#             continent           location total_cases_per_million  \
# 257407  South America          Argentina                     NaN
# 257408  North America             Mexico                     NaN
# 257405  South America          Argentina                     NaN
# 257406  North America             Mexico                     NaN
# 257403  South America          Argentina                     NaN
# ...               ...                ...                     ...
# 227           Oceania  Wallis and Futuna              295532.942
# 228           Oceania              World               84400.794
# 229              Asia              Yemen                 354.487
# 230            Africa             Zambia               17100.741
# 231            Africa           Zimbabwe               16119.749
#
#         new_cases_per_million total_deaths_per_million  \
# 257407                    NaN                      NaN
# 257408                    NaN                      NaN
# 257405                    NaN                      NaN
# 257406                    NaN                      NaN
# 257403                    NaN                      NaN
# ...                       ...                      ...
# 227                     0.000                  603.656
# 228                    22.487                  859.646
# 229                     0.000                   64.072
# 230                     0.000                  202.371
# 231                     0.000                  346.741
#
#         new_deaths_per_million  reproduction_rate  icu_patients_per_million  \
# 257407                     NaN                NaN                       NaN
# 257408                     NaN                NaN                       NaN
# 257405                     NaN                NaN                       NaN
# 257406                     NaN                NaN                       NaN
# 257403                     NaN                NaN                       NaN
# ...                        ...                ...                       ...
# 227                      0.000                NaN                     0.758
# 228                      0.149                NaN                     0.758
# 229                      0.000                NaN                     0.758
# 230                      0.000                NaN                     0.758
# 231                      0.000                NaN                     0.758
#
#         hosp_patients_per_million  total_tests_per_thousand  ...  \
# 257407                        NaN                     0.000  ...
# 257408                        NaN                     0.000  ...
# 257405                        NaN                     0.002  ...
# 257406                        NaN                     0.001  ...
# 257403                        NaN                     0.002  ...
# ...                           ...                       ...  ...
# 227                        60.857                       NaN  ...
# 228                        60.857                       NaN  ...
# 229                        60.857                       NaN  ...
# 230                        60.857                       NaN  ...
# 231                        60.857                       NaN  ...
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 257407                 5.50          16.200        27.700
# 257408                13.06           6.900        21.400
# 257405                 5.50          16.200        27.700
# 257406                13.06           6.900        21.400
# 257403                 5.50          16.200        27.700
# ...                     ...             ...           ...
# 227                    6.00           1.000        45.900
# 228                    8.51           6.434        34.635
# 229                    5.35           7.600        29.200
# 230                    3.94           3.100        24.700
# 231                    1.82           1.600        30.700
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 257407                     NaN                       5.000            76.67
# 257408                  87.847                       1.380            75.05
# 257405                  87.847                       5.000            76.67
# 257406                  87.847                       1.380            75.05
# 257403                  87.847                       5.000            76.67
# ...                        ...                         ...              ...
# 227                     85.847                       2.600            79.94
# 228                     60.130                       2.705            72.58
# 229                     49.542                       0.700            66.12
# 230                     13.938                       2.000            63.89
# 231                     36.791                       1.700            61.49
#
#         human_development_index    population  excess_mortality  \
# 257407                    0.845  4.551032e+07               NaN
# 257408                    0.779  1.275041e+08               NaN
# 257405                    0.845  4.551032e+07               NaN
# 257406                    0.779  1.275041e+08               NaN
# 257403                    0.845  4.551032e+07               NaN
# ...                         ...           ...               ...
# 227                       0.704  1.159600e+04               NaN
# 228                       0.737  7.975105e+09               NaN
# 229                       0.470  3.369661e+07               NaN
# 230                       0.584  2.001767e+07               NaN
# 231                       0.571  1.632054e+07               NaN
#
#         excess_mortality_cumulative_per_million
# 257407                                      NaN
# 257408                                      NaN
# 257405                                      NaN
# 257406                                      NaN
# 257403                                      NaN
# ...                                         ...
# 227                                         NaN
# 228                                         NaN
# 229                                         NaN
# 230                                         NaN
# 231                                         NaN
#
# [257408 rows x 38 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isna().groupby(df.continent).sum()
# Out:
#                continent  location  date  total_cases_per_million  \
# continent
# Africa                 0         0     0                       89
# Asia                   0         0     0                     2118
# Europe                 0         0     0                     5752
# North America          0         0     0                     2290
# Oceania                0         0     0                     4065
# South America          0         0     0                       63
#
#                new_cases_per_million  total_deaths_per_million  \
# continent
# Africa                           132                      2868
# Asia                            2174                      6041
# Europe                          5853                      8261
# North America                   2312                      6534
# Oceania                         4093                      8871
# South America                     95                      1270
#
#                new_deaths_per_million  reproduction_rate  \
# continent
# Africa                           2889               5603
# Asia                             6070               8862
# Europe                           8426              13125
# North America                    6562              17393
# Oceania                          8883              12289
# South America                    1294               1941
#
#                icu_patients_per_million  hosp_patients_per_million  ...  \
# continent                                                           ...
# Africa                            56751                      57617  ...
# Asia                              51496                      52231  ...
# Europe                            34584                      28247  ...
# North America                     36618                      36618  ...
# Oceania                           17295                      17295  ...
# South America                     11794                      13491  ...
#
#                diabetes_prevalence  female_smokers  male_smokers  \
# continent
# Africa                         892           20048         20048
# Asia                          3997           13193         13193
# Europe                       10993           15320         15320
# North America                 5814           24527         25598
# Oceania                       3553            9798          9798
# South America                 1047            4256          5332
#
#                handwashing_facilities  hospital_beds_per_thousand  \
# continent
# Africa                          11558                       15758
# Asia                            26948                        6207
# Europe                          55664                       12073
# North America                   24616                       13861
# Oceania                         15644                       10636
# South America                    7574                        1047
#
#                life_expectancy  human_development_index  population  \
# continent
# Africa                       0                     1958           0
# Asia                       691                     3943           0
# Europe                    6699                    13157           0
# North America                0                    13861           0
# Oceania                    441                     7851           0
# South America                0                     1047           0
#
#                excess_mortality  excess_mortality_cumulative_per_million
# continent
# Africa                    58171                                    58171
# Asia                      53516                                    53516
# Europe                    53884                                    53884
# North America             37545                                    37545
# Oceania                   18012                                    18012
# South America             13295                                    13295
#
# [6 rows x 39 columns]

# %%
null_df
# Out:
#             new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 2020-01-05                  0.000                   0.000               0.00
# 2020-01-12                  0.000                   0.000               0.00
# 2020-01-19                  0.000                   0.000               0.00
# 2020-01-26                 10.555                   0.056              26.91
# 2020-02-02                 31.426                   0.479              43.31
# ...                           ...                     ...                ...
# 2023-01-22              74094.465                 757.967               0.00
# 2023-01-29              63983.000                 408.100               0.00
# 2023-02-05              47598.227                 359.521               0.00
# 2023-02-12              69149.735                 389.999               0.00
# 2023-02-19              39566.380                  79.667               0.00
#
#             icu_patients_per_million  hosp_patients_per_million  \
# date
# 2020-01-05                     0.000                      0.000
# 2020-01-12                     0.000                      0.754
# 2020-01-19                     0.000                      0.754
# 2020-01-26                     0.000                      0.000
# 2020-02-02                     0.000                      0.000
# ...                              ...                        ...
# 2023-01-22                   894.783                  17043.956
# 2023-01-29                   789.485                  13631.543
# 2023-02-05                   697.504                  12177.723
# 2023-02-12                   464.518                   6475.035
# 2023-02-19                   102.699                   1189.276
#
#             total_tests_per_thousand  new_tests_per_thousand  tests_per_case  \
# date
# 2020-01-05                     0.018                   0.007             0.0
# 2020-01-12                     0.105                   0.012            51.7
# 2020-01-19                     0.204                   0.013           176.5
# 2020-01-26                     0.336                   0.031            30.0
# 2020-02-02                     1.249                   0.092          1117.3
# ...                              ...                     ...             ...
# 2023-01-22                     0.000                   0.000             0.0
# 2023-01-29                     0.000                   0.000             0.0
# 2023-02-05                     0.000                   0.000             0.0
# 2023-02-12                     0.000                   0.000             0.0
# 2023-02-19                     0.000                   0.000             0.0
#
#             total_boosters  new_vaccinations  ...  diabetes_prevalence  \
# date                                          ...
# 2020-01-05    0.000000e+00               0.0  ...               106.88
# 2020-01-12    0.000000e+00               0.0  ...               188.13
# 2020-01-19    0.000000e+00               0.0  ...               188.13
# 2020-01-26    0.000000e+00               0.0  ...               601.88
# 2020-02-02    0.000000e+00               0.0  ...              1427.24
# ...                    ...               ...  ...                  ...
# 2023-01-22    6.645799e+10        60943464.0  ...             11968.53
# 2023-01-29    6.661262e+10        33901953.0  ...             11968.53
# 2023-02-05    6.644153e+10        28196265.0  ...             11968.53
# 2023-02-12    6.498252e+10         8137457.0  ...             11968.53
# 2023-02-19    1.811422e+10          775546.0  ...              3419.58
#
#             female_smokers  male_smokers  handwashing_facilities  \
# date
# 2020-01-05         119.300       323.100                 620.575
# 2020-01-12         225.100       705.600                1249.619
# 2020-01-19         225.100       705.600                1249.619
# 2020-01-26         597.270      2215.775                1989.221
# 2020-02-02        1723.438      5295.545                3621.587
# ...                    ...           ...                     ...
# 2023-01-22       11102.938     33403.545               33430.103
# 2023-01-29       11102.938     33403.545               33430.103
# 2023-02-05       11102.938     33403.545               33430.103
# 2023-02-12       11102.938     33403.545               33430.103
# 2023-02-19        3172.268      9543.870                9551.458
#
#             hospital_beds_per_thousand  life_expectancy  \
# date
# 2020-01-05                      36.100           912.90
# 2020-01-12                      69.620          1756.12
# 2020-01-19                      69.620          2077.96
# 2020-01-26                     293.115          6573.26
# 2020-02-02                     627.695         14520.63
# ...                                ...              ...
# 2023-01-22                    3698.681        111998.39
# 2023-01-29                    3698.681        111998.39
# 2023-02-05                    3698.681        111998.39
# 2023-02-12                    3698.681        111998.39
# 2023-02-19                    1056.766         31999.54
#
#             human_development_index    population  excess_mortality  \
# date
# 2020-01-05                    9.674  1.008466e+09              0.07
# 2020-01-12                   18.565  1.716157e+09              1.94
# 2020-01-19                   18.565  1.811731e+09             -0.12
# 2020-01-26                   59.463  1.199717e+11             -9.67
# 2020-02-02                  142.315  1.779086e+11            -55.45
# ...                             ...           ...               ...
# 2023-01-22                  955.920  2.266475e+11              0.00
# 2023-01-29                  955.920  2.266475e+11              0.00
# 2023-02-05                  955.920  2.266413e+11              0.00
# 2023-02-12                  955.920  2.263643e+11              0.00
# 2023-02-19                  273.120  6.462204e+10              0.00
#
#             excess_mortality_cumulative_per_million
# date
# 2020-01-05                                 0.097620
# 2020-01-12                                 2.650830
# 2020-01-19                                 2.488129
# 2020-01-26                              -107.147247
# 2020-02-02                              -770.582793
# ...                                             ...
# 2023-01-22                                 0.000000
# 2023-01-29                                 0.000000
# 2023-02-05                                 0.000000
# 2023-02-12                                 0.000000
# 2023-02-19                                 0.000000
#
# [164 rows x 34 columns]
